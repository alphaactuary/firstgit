# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = np.arange(1, 50)
y = np.sin(x)

# %%
plt.plot(x, y)
plt.xlabel("values")
plt.ylabel("Sin")
plt.title("Sin Curve")
plt.show()
